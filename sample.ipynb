# %% [markdown]
# # Tratamento de Dados com Python (Pandas)
#
# ### Cenário:
# Recebemos um dataset de clientes com informações de compra.
# Antes de realizar qualquer análise, precisamos garantir a qualidade desses dados.
#
# Objetivo da aula:
# - Diagnosticar problemas
# - Corrigir inconsistências
# - Preparar os dados para análise

# %% [markdown]
# ## 1. Carregando os dados
#
# Antes de limpar, precisamos entender o que recebemos.

# %%
# Execute esta célula para instalar as bibliotecas necessárias
# !pip install pandas jupyter

# %%
import pandas as pd

df = pd.read_csv("./data/clientes_senac.csv")

# mostrando o conteúdo da variável
df

# %%
# Vejamos o se há algo de errado com o dataframe
df.info()

# %%
# Vejamos o impacto dos dados faltantes
df.isnull().sum()
# Out:
# id              0
# nome            0
# idade           2
# email           0
# valor_compra    2
# data_compra     0
# cidade          0
# dtype: int64

# %% [markdown]
# ## 2. Removendo espaços desnecessários

# %%
# Limpando os dados
df['nome'] = df['nome'].str.strip()
df['valor_compra'] = df['valor_compra'].astype(str).str.strip()

df
# Out:
#     id              nome  idade                email valor_compra data_compra  \
# 0    1         Ana Souza   29.0        ana@email.com       150.50  2025-01-10
# 1    2        Bruno Lima    NaN      bruno@email.com          200  10/02/2025
# 2    3      Carla Mendes   34.0      carla@email.com       350.75  2025/03/15
# 3    4      Daniel Alves   41.0     daniel@email.com       R$ 420  2025-04-20
# 4    5     Eduarda Silva   27.0    eduarda@email.com       180.00  15-05-2025
# 5    6      Felipe Costa   19.0     felipe@email.com           90  2025-06-01
# 6    7    Gabriela Rocha   31.0   gabriela@email.com       250.40  2025-07-12
# 7    8  Henrique Martins    NaN   henrique@email.com       300.10  2025-08-03
# 8    9         Ana Souza   29.0        ana@email.com       150.50  2025-01-10
# 9   10    Isabela Santos   45.0    isabela@email.com          500  2025-09-25
# 10  11        João Pedro   38.0  joaopedro@email.com       275.90  2025-10-05
# 11  12   Larissa Almeida   22.0    larissa@email.com         erro  2025-11-18
# 12  13   Marcos Oliveira   60.0     marcos@email.com      1000.00  2025-12-01
# 13  14   Natalia Pereira   33.0    natalia@email.com          NaN  2025-12-15
# 14  15      Otavio Ramos   28.0     otavio@email.com       350.00  2025-13-01
# 15  16   Natalia Pereira   33.0    natalia@email.com          NaN  2025-12-15
#
#              cidade
# 0    Rio de Janeiro
# 1           Niterói
# 2    Rio de Janeiro
# 3   Duque de Caxias
# 4    Rio de Janeiro
# 5           Niterói
# 6    Rio de Janeiro
# 7       São Gonçalo
# 8    Rio de Janeiro
# 9    Rio de Janeiro
# 10          Niterói
# 11   Rio de Janeiro
# 12   Rio de Janeiro
# 13  Duque de Caxias
# 14   Rio de Janeiro
# 15  Duque de Caxias

# %% [markdown]
# ## 3. Corrigindo valores monetários

# %%
# Convertendo os valores monetários
df['valor_compra'] = (
    df['valor_compra']
    .str.replace("R$", "", regex=False)
)

df['valor_compra'] = pd.to_numeric(df['valor_compra'], errors='coerce')

# df['valor_compra'].describe()

df[['valor_compra']]
# Out:
#     valor_compra
# 0         150.50
# 1         200.00
# 2         350.75
# 3         420.00
# 4         180.00
# 5          90.00
# 6         250.40
# 7         300.10
# 8         150.50
# 9         500.00
# 10        275.90
# 11           NaN
# 12       1000.00
# 13           NaN
# 14        350.00
# 15           NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            16 non-null     int64
#  1   nome          16 non-null     str
#  2   idade         14 non-null     float64
#  3   email         16 non-null     str
#  4   valor_compra  13 non-null     float64
#  5   data_compra   16 non-null     str
#  6   cidade        16 non-null     str
# dtypes: float64(2), int64(1), str(4)
# memory usage: 1.0 KB

# %% [markdown]
# ## 4. Normalizando formatos de data com Regex
#
# Vamos identificar padrões diferentes e convertê-los para o formato ISO (YYYY-MM-DD).

# %%
# --- Padronização de Datas com Regex ---

# Garantir que a coluna é do tipo string para aplicar regex
df['data_compra'] = df['data_compra'].astype(str)

# Padrão 1: dd/mm/yyyy -> yyyy-mm-dd
# Exemplo: 15/03/2025 -> 2025-03-15
df['data_compra'] = df['data_compra'].str.replace(
    r'^(\d{2})/(\d{2})/(\d{4})$',  # Captura: (Dia)/(Mês)/(Ano)
    r'\3-\2-\1',               # Substitui por: Ano-Mês-Dia
    regex=True
)

# Padrão 2: yyyy/mm/dd -> yyyy-mm-dd
# Exemplo: 2025/03/15 -> 2025-03-15
df['data_compra'] = df['data_compra'].str.replace(
    r'^(\d{4})/(\d{2})/(\d{2})$',  # Captura: (Ano)/(Mês)/(Dia)
    r'\1-\2-\3',               # Substitui por: Ano-Mês-Dia
    regex=True
)

# Padrão 3: dd-mm-yyyy -> yyyy-mm-dd
# Exemplo: 15-03-2025 -> 2025-03-15
df['data_compra'] = df['data_compra'].str.replace(
    r'^(\d{2})-(\d{2})-(\d{4})$',  # Captura: (Dia)-(Mês)-(Ano)
    r'\3-\2-\1',               # Substitui por: Ano-Mês-Dia
    regex=True
)

# Exibir as tabela após a formatação
df[['data_compra']]
# Out:
#    data_compra
# 0   2025-01-10
# 1   2025-02-10
# 2   2025-03-15
# 3   2025-04-20
# 4   2025-05-15
# 5   2025-06-01
# 6   2025-07-12
# 7   2025-08-03
# 8   2025-01-10
# 9   2025-09-25
# 10  2025-10-05
# 11  2025-11-18
# 12  2025-12-01
# 13  2025-12-15
# 14  2025-13-01
# 15  2025-12-15

# %%
df['data_compra'] = pd.to_datetime(
    df['data_compra'],
    errors='coerce'
)

df[['data_compra']]
# Out:
#    data_compra
# 0   2025-01-10
# 1   2025-02-10
# 2   2025-03-15
# 3   2025-04-20
# 4   2025-05-15
# 5   2025-06-01
# 6   2025-07-12
# 7   2025-08-03
# 8   2025-01-10
# 9   2025-09-25
# 10  2025-10-05
# 11  2025-11-18
# 12  2025-12-01
# 13  2025-12-15
# 14         NaT
# 15  2025-12-15

# %% [markdown]
# ## 5. Removendo registros duplicados

# %%
# Tratamento de dados duplicados
# keep=False é o segredo: ele marca TODAS as ocorrências como True (o original e a cópia)
# Se não usar keep=False, ele mostra apenas a repetição e esconde o original
duplicadas = df[df.duplicated(subset='email', keep=False)]
duplicadas
# Out:
#     id             nome  idade              email  valor_compra data_compra  \
# 0    1        Ana Souza   29.0      ana@email.com         150.5  2025-01-10
# 8    9        Ana Souza   29.0      ana@email.com         150.5  2025-01-10
# 13  14  Natalia Pereira   33.0  natalia@email.com           NaN  2025-12-15
# 15  16  Natalia Pereira   33.0  natalia@email.com           NaN  2025-12-15
#
#              cidade
# 0    Rio de Janeiro
# 8    Rio de Janeiro
# 13  Duque de Caxias
# 15  Duque de Caxias

# %%
# Verificando o tamanho do DataFrame (linhas, colunas), antes de remover duplicadas
df.shape
# Out:
# (16, 7)

# %%
df.drop_duplicates(subset='email', inplace=True)

# Verificando o número de linhas após a remoção de duplicatas
df.shape
# Out:
# (14, 7)

# %% [markdown]
# ## 6. Tratando valores ausentes

# %%
# Conta quantos valores nulos existem em cada coluna
df.isnull().sum()
# Out:
# id              0
# nome            0
# idade           2
# email           0
# valor_compra    2
# data_compra     1
# cidade          0
# dtype: int64

# %%
# Preenchendo a idade vazia com a mediana das idades existentes
mediana_idade = df['idade'].median()
df['idade'] = df['idade'].fillna(mediana_idade)

# Preenchendo o valor de compra vazio com 0 (assumindo que não houve compra ou foi erro)
df['valor_compra'] = df['valor_compra'].fillna(0)


# Verificando se ainda sobrou algum nulo
df.isnull().sum()
# Out:
# id              0
# nome            0
# idade           0
# email           0
# valor_compra    0
# data_compra     1
# cidade          0
# dtype: int64

# %%
# Remove linhas onde a data_compra ainda é nula (NaT)
df = df.dropna(subset=['data_compra'])

# Verifica o tamanho final da tabela
df.shape
# Out:
# (13, 7)

# %%
# Resultado final
df.info()
df
# Out:
# <class 'pandas.DataFrame'>
# Index: 13 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            13 non-null     int64
#  1   nome          13 non-null     str
#  2   idade         13 non-null     float64
#  3   email         13 non-null     str
#  4   valor_compra  13 non-null     float64
#  5   data_compra   13 non-null     datetime64[us]
#  6   cidade        13 non-null     str
# dtypes: datetime64[us](1), float64(2), int64(1), str(3)
# memory usage: 832.0 bytes
#     id              nome  idade                email  valor_compra  \
# 0    1         Ana Souza   29.0        ana@email.com        150.50
# 1    2        Bruno Lima   32.0      bruno@email.com        200.00
# 2    3      Carla Mendes   34.0      carla@email.com        350.75
# 3    4      Daniel Alves   41.0     daniel@email.com        420.00
# 4    5     Eduarda Silva   27.0    eduarda@email.com        180.00
# 5    6      Felipe Costa   19.0     felipe@email.com         90.00
# 6    7    Gabriela Rocha   31.0   gabriela@email.com        250.40
# 7    8  Henrique Martins   32.0   henrique@email.com        300.10
# 9   10    Isabela Santos   45.0    isabela@email.com        500.00
# 10  11        João Pedro   38.0  joaopedro@email.com        275.90
# 11  12   Larissa Almeida   22.0    larissa@email.com          0.00
# 12  13   Marcos Oliveira   60.0     marcos@email.com       1000.00
# 13  14   Natalia Pereira   33.0    natalia@email.com          0.00
#
#    data_compra           cidade
# 0   2025-01-10   Rio de Janeiro
# 1   2025-02-10          Niterói
# 2   2025-03-15   Rio de Janeiro
# 3   2025-04-20  Duque de Caxias
# 4   2025-05-15   Rio de Janeiro
# 5   2025-06-01          Niterói
# 6   2025-07-12   Rio de Janeiro
# 7   2025-08-03      São Gonçalo
# 9   2025-09-25   Rio de Janeiro
# 10  2025-10-05          Niterói
# 11  2025-11-18   Rio de Janeiro
# 12  2025-12-01   Rio de Janeiro
# 13  2025-12-15  Duque de Caxias

# %% [markdown]
# ## Atividade Prática!!
#
# 1. Baixar e Carregar o CSV
# 2. Remover as linhas com valores vazios
# 3. Corrigir valores monetários
# 4. Validar datas
# 5. Remover registros duplicados
# 6. Tratar valores ausentes

# %% [markdown]
# # Glossário de Funções e Métodos
#
# Aqui está uma explicação detalhada das funções que utilizamos e como elas se conectam.
#
# ### Pandas (Manipulação de Dados)
# - **`pd.read_csv()`**: Carrega um arquivo CSV para um DataFrame (tabela).
# - **`df.head(n)`**: Mostra as primeiras `n` linhas.
# - **`df.info()`**: Mostra o resumo técnico (tipos de dados, memória usada, nulos).
# - **`df.isnull().sum()`**: Conta quantos valores vazios existem em cada coluna.
# - **`df.duplicated()`**: Identifica linhas duplicadas.
# - **`df.drop_duplicates()`**: Remove as linhas duplicadas.
# - **`df.fillna(valor)`**: Preenche valores vazios (`NaN`) com um valor específico.
#
# ### Manipulação de Strings (.str)
# - **`.astype(str)`**: Converte a coluna para texto.
# - **`.str.strip()`**: Remove espaços em branco das extremidades.
# - **`.str.replace(antigo, novo)`**: Substitui pedaços de texto.
#   - Com `regex=True`, usa padrões inteligentes de busca.
#
# ### Conversão de Tipos
# - **`pd.to_numeric(..., errors='coerce')`**: Converte para número. Se falhar (ex: texto "erro"), vira `NaN`.
# - **`pd.to_datetime(..., errors='coerce')`**: Converte para data. Se falhar, vira `NaT` (Not a Time).
